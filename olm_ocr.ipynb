# %% [markdown]
# # olmOCR Google Colab Setup
# # This notebook installs and runs olmOCR on Google Colab

# %%
# 1. Install system dependencies
# !apt-get update

# Accept Microsoft fonts EULA non-interactively
# !echo ttf-mscorefonts-installer msttcorefonts/accepted-mscorefonts-eula select true | sudo debconf-set-selections

# Install the required packages - use -y flag to avoid prompts
# !apt-get install -y poppler-utils ttf-mscorefonts-installer fonts-crosextra-caladea fonts-crosextra-carlito gsfonts lcdf-typetools ghostscript

# Don't fail if Microsoft fonts aren't found in cache
# !fc-cache -f -v
print("Font cache updated")
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   aglfn cabextract distro-info dvisvgm fonts-droid-fallback fonts-lmodern fonts-urw-base35
#   libfontenc1 libgs9 libgs9-common libidn12 libijs-0.35 libjbig2dec0 libkpathsea6 libmspack0
#   libptexenc1 libsynctex2 libteckit0 libtexlua53 libtexluajit2 libwoff1 libzzip-0-13 lmodern
#   poppler-data ps2eps python3-chardet python3-debconf python3-debian python3-distro-info
#   python3-distupgrade python3-update-manager python3-yaml t1utils tex-common texlive-base
#   texlive-binaries texlive-font-utils ubuntu-advantage-tools ubuntu-pro-client
#   ubuntu-pro-client-l10n ubuntu-release-upgrader-core update-manager-core update-notifier-common
#   xfonts-encodings xfonts-utils zstd
# Suggested packages:
#   shunit2 fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre ghostscript-x
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum debhelper perl-tk xpdf | pdf-viewer xzdec
#   psutils
# Recommended packages:
#   fonts-noto-mono
# The following NEW packages will be installed:
#   aglfn cabextract distro-info dvisvgm fonts-crosextra-caladea fonts-crosextra-carlito
#   fonts-lmodern fonts-urw-base35 ghostscript gsfonts lcdf-typetools libfontenc1 libgs9
#   libgs9-common libidn12 libijs-0.35 libjbig2dec0 libkpathsea6 libmspack0 libptexenc1 libsynctex2
#   libteckit0 libtexlua53 libtexluajit2 libwoff1 libzzip-0-13 lmodern poppler-data poppler-utils
#   ps2eps python3-chardet python3-debconf python3-debian python3-distro-info python3-distupgrade
#   python3-update-manager python3-yaml t1utils tex-common texlive-base texlive-binaries
#   texlive-font-utils ttf-mscorefonts-installer ubuntu-advantage-tools ubuntu-pro-client
#   ubuntu-pro-client-l10n ubuntu-release-upgrader-core update-manager-core update-notifier-common
#   xfonts-encodings xfonts-utils zstd
# The following packages will be upgraded:
#   fonts-droid-fallback
# 1 upgraded, 52 newly installed, 0 to remove and 29 not upgraded.
# 1 not fully installed or removed.
# Need to get 74.9 MB of archives.
# After this operation, 238 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tex-common all 6.17 [33.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmspack0 amd64 0.10.1-2build2 [39.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 cabextract amd64 1.9-3 [23.4 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-chardet all 4.0.0-1 [98.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 zstd amd64 1.4.8+dfsg-3build1 [603 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-debian all 0.1.43ubuntu1.1 [107 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-debconf all 1.5.79ubuntu1 [3,914 B]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-distro-info all 1.1ubuntu0.2 [6,554 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 python3-yaml amd64 5.4.1-1ubuntu1 [129 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-distupgrade all 1:22.04.20 [106 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-update-manager all 1:22.04.21 [39.1 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ubuntu-release-upgrader-core all 1:22.04.20 [26.2 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 distro-info amd64 1.1ubuntu0.2 [18.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ubuntu-pro-client amd64 34~22.04 [221 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ubuntu-advantage-tools all 34~22.04 [10.9 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 update-manager-core all 1:22.04.21 [11.5 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 update-notifier-common all 3.192.54.8 [185 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 ttf-mscorefonts-installer all 3.8ubuntu2 [24.9 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ubuntu-pro-client-l10n amd64 34~22.04 [19.1 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.10 [752 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.10 [5,031 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libkpathsea6 amd64 2021.20210626.59705-1ubuntu0.2 [60.4 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwoff1 amd64 1.0.2-1build4 [45.2 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 dvisvgm amd64 2.13.1-1 [1,221 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-caladea all 20130214-2.1 [82.4 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-carlito all 20130920-1.1 [743 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-lmodern all 2.004.5-6.1 [4,532 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ghostscript amd64 9.55.0~dfsg1-0ubuntu5.10 [49.4 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.5 [3,120 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lcdf-typetools amd64 2.108-2 [702 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libptexenc1 amd64 2021.20210626.59705-1ubuntu0.2 [39.1 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsynctex2 amd64 2021.20210626.59705-1ubuntu0.2 [55.6 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libteckit0 amd64 2.5.11+ds1-1 [421 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtexlua53 amd64 2021.20210626.59705-1ubuntu0.2 [120 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtexluajit2 amd64 2021.20210626.59705-1ubuntu0.2 [267 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzzip-0-13 amd64 0.13.72+dfsg.1-1.1 [27.0 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lmodern all 2.004.5-6.1 [9,471 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.6 [186 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ps2eps amd64 1.68+binaryfree-3 [33.5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 t1utils amd64 1.41-4build2 [61.3 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 texlive-binaries amd64 2021.20210626.59705-1ubuntu0.2 [9,860 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-base all 2021.20220204-1 [21.0 MB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-font-utils all 2021.20220204-1 [4,097 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 aglfn all 1.7+git20191031.4036a9c-2 [30.6 kB]
# Fetched 74.9 MB in 6s (12.7 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# (Reading database ... 124947 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) over (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../01-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../02-tex-common_6.17_all.deb ...
# Unpacking tex-common (6.17) ...
# Selecting previously unselected package libmspack0:amd64.
# Preparing to unpack .../03-libmspack0_0.10.1-2build2_amd64.deb ...
# Unpacking libmspack0:amd64 (0.10.1-2build2) ...
# Selecting previously unselected package cabextract.
# Preparing to unpack .../04-cabextract_1.9-3_amd64.deb ...
# Unpacking cabextract (1.9-3) ...
# Selecting previously unselected package libfontenc1:amd64.
# Preparing to unpack .../05-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../06-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../07-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package python3-chardet.
# Preparing to unpack .../08-python3-chardet_4.0.0-1_all.deb ...
# Unpacking python3-chardet (4.0.0-1) ...
# Selecting previously unselected package zstd.
# Preparing to unpack .../09-zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Selecting previously unselected package python3-debian.
# Preparing to unpack .../10-python3-debian_0.1.43ubuntu1.1_all.deb ...
# Unpacking python3-debian (0.1.43ubuntu1.1) ...
# Selecting previously unselected package python3-debconf.
# Preparing to unpack .../11-python3-debconf_1.5.79ubuntu1_all.deb ...
# Unpacking python3-debconf (1.5.79ubuntu1) ...
# Selecting previously unselected package python3-distro-info.
# Preparing to unpack .../12-python3-distro-info_1.1ubuntu0.2_all.deb ...
# Unpacking python3-distro-info (1.1ubuntu0.2) ...
# Selecting previously unselected package python3-yaml.
# Preparing to unpack .../13-python3-yaml_5.4.1-1ubuntu1_amd64.deb ...
# Unpacking python3-yaml (5.4.1-1ubuntu1) ...
# Selecting previously unselected package python3-distupgrade.
# Preparing to unpack .../14-python3-distupgrade_1%3a22.04.20_all.deb ...
# Unpacking python3-distupgrade (1:22.04.20) ...
# Selecting previously unselected package python3-update-manager.
# Preparing to unpack .../15-python3-update-manager_1%3a22.04.21_all.deb ...
# Unpacking python3-update-manager (1:22.04.21) ...
# Selecting previously unselected package ubuntu-release-upgrader-core.
# Preparing to unpack .../16-ubuntu-release-upgrader-core_1%3a22.04.20_all.deb ...
# Unpacking ubuntu-release-upgrader-core (1:22.04.20) ...
# Selecting previously unselected package distro-info.
# Preparing to unpack .../17-distro-info_1.1ubuntu0.2_amd64.deb ...
# Unpacking distro-info (1.1ubuntu0.2) ...
# Selecting previously unselected package ubuntu-pro-client.
# Preparing to unpack .../18-ubuntu-pro-client_34~22.04_amd64.deb ...
# Unpacking ubuntu-pro-client (34~22.04) ...
# Selecting previously unselected package ubuntu-advantage-tools.
# Preparing to unpack .../19-ubuntu-advantage-tools_34~22.04_all.deb ...
# Unpacking ubuntu-advantage-tools (34~22.04) ...
# Selecting previously unselected package update-manager-core.
# Preparing to unpack .../20-update-manager-core_1%3a22.04.21_all.deb ...
# Unpacking update-manager-core (1:22.04.21) ...
# Selecting previously unselected package update-notifier-common.
# Preparing to unpack .../21-update-notifier-common_3.192.54.8_all.deb ...
# Unpacking update-notifier-common (3.192.54.8) ...
# Selecting previously unselected package ttf-mscorefonts-installer.
# Preparing to unpack .../22-ttf-mscorefonts-installer_3.8ubuntu2_all.deb ...
# mscorefonts-eula license has already been accepted
# Unpacking ttf-mscorefonts-installer (3.8ubuntu2) ...
# Selecting previously unselected package ubuntu-pro-client-l10n.
# Preparing to unpack .../23-ubuntu-pro-client-l10n_34~22.04_amd64.deb ...
# Unpacking ubuntu-pro-client-l10n (34~22.04) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../24-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../25-libgs9-common_9.55.0~dfsg1-0ubuntu5.10_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.10) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../26-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../27-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../28-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../29-libgs9_9.55.0~dfsg1-0ubuntu5.10_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.10) ...
# Selecting previously unselected package libkpathsea6:amd64.
# Preparing to unpack .../30-libkpathsea6_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libkpathsea6:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../31-libwoff1_1.0.2-1build4_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build4) ...
# Selecting previously unselected package dvisvgm.
# Preparing to unpack .../32-dvisvgm_2.13.1-1_amd64.deb ...
# Unpacking dvisvgm (2.13.1-1) ...
# Selecting previously unselected package fonts-crosextra-caladea.
# Preparing to unpack .../33-fonts-crosextra-caladea_20130214-2.1_all.deb ...
# Unpacking fonts-crosextra-caladea (20130214-2.1) ...
# Selecting previously unselected package fonts-crosextra-carlito.
# Preparing to unpack .../34-fonts-crosextra-carlito_20130920-1.1_all.deb ...
# Unpacking fonts-crosextra-carlito (20130920-1.1) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../35-fonts-lmodern_2.004.5-6.1_all.deb ...
# Unpacking fonts-lmodern (2.004.5-6.1) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../36-ghostscript_9.55.0~dfsg1-0ubuntu5.10_amd64.deb ...
# Unpacking ghostscript (9.55.0~dfsg1-0ubuntu5.10) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../37-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.5_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.5) ...
# Selecting previously unselected package lcdf-typetools.
# Preparing to unpack .../38-lcdf-typetools_2.108-2_amd64.deb ...
# Unpacking lcdf-typetools (2.108-2) ...
# Selecting previously unselected package libptexenc1:amd64.
# Preparing to unpack .../39-libptexenc1_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libptexenc1:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libsynctex2:amd64.
# Preparing to unpack .../40-libsynctex2_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libsynctex2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libteckit0:amd64.
# Preparing to unpack .../41-libteckit0_2.5.11+ds1-1_amd64.deb ...
# Unpacking libteckit0:amd64 (2.5.11+ds1-1) ...
# Selecting previously unselected package libtexlua53:amd64.
# Preparing to unpack .../42-libtexlua53_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libtexlua53:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libtexluajit2:amd64.
# Preparing to unpack .../43-libtexluajit2_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libtexluajit2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libzzip-0-13:amd64.
# Preparing to unpack .../44-libzzip-0-13_0.13.72+dfsg.1-1.1_amd64.deb ...
# Unpacking libzzip-0-13:amd64 (0.13.72+dfsg.1-1.1) ...
# Selecting previously unselected package lmodern.
# Preparing to unpack .../45-lmodern_2.004.5-6.1_all.deb ...
# Unpacking lmodern (2.004.5-6.1) ...
# Selecting previously unselected package poppler-utils.
# Preparing to unpack .../46-poppler-utils_22.02.0-2ubuntu0.6_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.6) ...
# Selecting previously unselected package ps2eps.
# Preparing to unpack .../47-ps2eps_1.68+binaryfree-3_amd64.deb ...
# Unpacking ps2eps (1.68+binaryfree-3) ...
# Selecting previously unselected package t1utils.
# Preparing to unpack .../48-t1utils_1.41-4build2_amd64.deb ...
# Unpacking t1utils (1.41-4build2) ...
# Selecting previously unselected package texlive-binaries.
# Preparing to unpack .../49-texlive-binaries_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking texlive-binaries (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package texlive-base.
# Preparing to unpack .../50-texlive-base_2021.20220204-1_all.deb ...
# Unpacking texlive-base (2021.20220204-1) ...
# Selecting previously unselected package texlive-font-utils.
# Preparing to unpack .../51-texlive-font-utils_2021.20220204-1_all.deb ...
# Unpacking texlive-font-utils (2021.20220204-1) ...
# Selecting previously unselected package aglfn.
# Preparing to unpack .../52-aglfn_1.7+git20191031.4036a9c-2_all.deb ...
# Unpacking aglfn (1.7+git20191031.4036a9c-2) ...
# Setting up distro-info (1.1ubuntu0.2) ...
# Setting up libwoff1:amd64 (1.0.2-1build4) ...
# Setting up libtexlua53:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up libtexluajit2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up python3-debconf (1.5.79ubuntu1) ...
# Setting up libmspack0:amd64 (0.10.1-2build2) ...
# Setting up python3-yaml (5.4.1-1ubuntu1) ...
# Setting up libzzip-0-13:amd64 (0.13.72+dfsg.1-1.1) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up fonts-crosextra-carlito (20130920-1.1) ...
# Setting up tex-common (6.17) ...
# update-language: texlive-base not installed and configured, doing nothing!
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up python3-chardet (4.0.0-1) ...
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up libteckit0:amd64 (2.5.11+ds1-1) ...
# Setting up aglfn (1.7+git20191031.4036a9c-2) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.5) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up t1utils (1.41-4build2) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up libkpathsea6:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up fonts-crosextra-caladea (20130214-2.1) ...
# Setting up fonts-lmodern (2.004.5-6.1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.6) ...
# Setting up python3-distro-info (1.1ubuntu0.2) ...
# Setting up ubuntu-pro-client (34~22.04) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/ua-reboot-cmds.service → /lib/systemd/system/ua-reboot-cmds.service.
# Created symlink /etc/systemd/system/timers.target.wants/ua-timer.timer → /lib/systemd/system/ua-timer.timer.
# Created symlink /etc/systemd/system/multi-user.target.wants/ubuntu-advantage.service → /lib/systemd/system/ubuntu-advantage.service.
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Setting up lcdf-typetools (2.108-2) ...
# Setting up libsynctex2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up ubuntu-pro-client-l10n (34~22.04) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.10) ...
# Setting up cabextract (1.9-3) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.10) ...
# Setting up dvisvgm (2.13.1-1) ...
# Setting up ghostscript (9.55.0~dfsg1-0ubuntu5.10) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libptexenc1:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up python3-debian (0.1.43ubuntu1.1) ...
# Setting up ps2eps (1.68+binaryfree-3) ...
# Setting up texlive-binaries (2021.20210626.59705-1ubuntu0.2) ...
# update-alternatives: using /usr/bin/xdvi-xaw to provide /usr/bin/xdvi.bin (xdvi.bin) in auto mode
# update-alternatives: using /usr/bin/bibtex.original to provide /usr/bin/bibtex (bibtex) in auto mode
# Setting up lmodern (2.004.5-6.1) ...
# Setting up ubuntu-advantage-tools (34~22.04) ...
# Setting up texlive-base (2021.20220204-1) ...
# /usr/bin/ucfr
# /usr/bin/ucfr
# /usr/bin/ucfr
# /usr/bin/ucfr
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXLIVEDIST...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXMFMAIN...
# mktexlsr: Updating /var/lib/texmf/ls-R...
# mktexlsr: Done.
# tl-paper: setting paper size for dvips to a4: /var/lib/texmf/dvips/config/config-paper.ps
# tl-paper: setting paper size for dvipdfmx to a4: /var/lib/texmf/dvipdfmx/dvipdfmx-paper.cfg
# tl-paper: setting paper size for xdvi to a4: /var/lib/texmf/xdvi/XDvi-paper
# tl-paper: setting paper size for pdftex to a4: /var/lib/texmf/tex/generic/tex-ini-files/pdftexconfig.tex
# Setting up texlive-font-utils (2021.20220204-1) ...
# Setting up python3-update-manager (1:22.04.21) ...
# Setting up python3-distupgrade (1:22.04.20) ...
# Setting up ubuntu-release-upgrader-core (1:22.04.20) ...
# Setting up update-manager-core (1:22.04.21) ...
# Setting up update-notifier-common (3.192.54.8) ...
# ttf-mscorefonts-installer: processing...
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/andale32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/andale32.exe [198 kB]
# Fetched 198 kB in 2s (94.4 kB/s)
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/arial32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/arial32.exe [554 kB]
# Fetched 554 kB in 27s (20.3 kB/s)
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/arialb32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/arialb32.exe [168 kB]
# Fetched 168 kB in 1s (221 kB/s)
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/comic32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/comic32.exe [246 kB]
# Fetched 246 kB in 1s (212 kB/s)
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/courie32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/courie32.exe [646 kB]
# Fetched 646 kB in 2s (404 kB/s)
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/georgi32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/georgi32.exe [392 kB]
# Fetched 392 kB in 1s (276 kB/s)
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/impact32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/impact32.exe [173 kB]
# Fetched 173 kB in 1s (133 kB/s)
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/times32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/times32.exe [662 kB]
# Fetched 662 kB in 1s (695 kB/s)
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/trebuc32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/trebuc32.exe [357 kB]
# Fetched 357 kB in 1s (259 kB/s)
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/verdan32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/verdan32.exe [352 kB]
# Fetched 352 kB in 1s (309 kB/s)
# ttf-mscorefonts-installer: downloading http://downloads.sourceforge.net/corefonts/webdin32.exe
# Get:1 http://downloads.sourceforge.net/corefonts/webdin32.exe [185 kB]
# Fetched 185 kB in 1s (141 kB/s)
#
# These fonts were provided by Microsoft "in the interest of cross-
# platform compatibility".  This is no longer the case, but they are
# still available from third parties.
#
# You are free to download these fonts and use them for your own use,
# but you may not redistribute them in modified form, including changes
# to the file name or packaging format.
#
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/andale32.exe
#   extracting fontinst.inf
#   extracting andale.inf
#   extracting fontinst.exe
#   extracting AndaleMo.TTF
#   extracting ADVPACK.DLL
#   extracting W95INF32.DLL
#   extracting W95INF16.DLL
#
# All done, no errors.
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/arial32.exe
#   extracting FONTINST.EXE
#   extracting fontinst.inf
#   extracting Ariali.TTF
#   extracting Arialbd.TTF
#   extracting Arialbi.TTF
#   extracting Arial.TTF
#
# All done, no errors.
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/arialb32.exe
#   extracting fontinst.exe
#   extracting fontinst.inf
#   extracting AriBlk.TTF
#
# All done, no errors.
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/comic32.exe
#   extracting fontinst.inf
#   extracting Comicbd.TTF
#   extracting Comic.TTF
#   extracting fontinst.exe
#
# All done, no errors.
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/courie32.exe
#   extracting cour.ttf
#   extracting courbd.ttf
#   extracting courbi.ttf
#   extracting fontinst.inf
#   extracting couri.ttf
#   extracting fontinst.exe
#
# All done, no errors.
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/georgi32.exe
#   extracting fontinst.inf
#   extracting Georgiaz.TTF
#   extracting Georgiab.TTF
#   extracting Georgiai.TTF
#   extracting Georgia.TTF
#   extracting fontinst.exe
#
# All done, no errors.
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/impact32.exe
#   extracting fontinst.exe
#   extracting Impact.TTF
#   extracting fontinst.inf
#
# All done, no errors.
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/times32.exe
#   extracting fontinst.inf
#   extracting Times.TTF
#   extracting Timesbd.TTF
#   extracting Timesbi.TTF
#   extracting Timesi.TTF
#   extracting FONTINST.EXE
#
# All done, no errors.
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/trebuc32.exe
#   extracting FONTINST.EXE
#   extracting trebuc.ttf
#   extracting Trebucbd.ttf
#   extracting trebucbi.ttf
#   extracting trebucit.ttf
#   extracting fontinst.inf
#
# All done, no errors.
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/verdan32.exe
#   extracting fontinst.exe
#   extracting fontinst.inf
#   extracting Verdanab.TTF
#   extracting Verdanai.TTF
#   extracting Verdanaz.TTF
#   extracting Verdana.TTF
#
# All done, no errors.
# Extracting cabinet: /var/lib/update-notifier/package-data-downloads/partial/webdin32.exe
#   extracting fontinst.exe
#   extracting Webdings.TTF
#   extracting fontinst.inf
#   extracting Licen.TXT
#
# All done, no errors.
# All fonts downloaded and installed.
# Created symlink /etc/systemd/system/timers.target.wants/update-notifier-download.timer → /lib/systemd/system/update-notifier-download.timer.
# Created symlink /etc/systemd/system/timers.target.wants/update-notifier-motd.timer → /lib/systemd/system/update-notifier-motd.timer.
# Setting up ttf-mscorefonts-installer (3.8ubuntu2) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for tex-common (6.17) ...
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Building format(s) --all.
# 	This may take some time... done.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 6 dirs
# /usr/share/fonts/X11: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/X11/Type1: caching, new cache contents: 40 fonts, 0 dirs
# /usr/share/fonts/X11/encodings: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/X11/encodings/large: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/X11/util: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cMap: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap: caching, new cache contents: 0 fonts, 5 dirs
# /usr/share/fonts/cmap/adobe-cns1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-gb1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-japan1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-japan2: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/cmap/adobe-korea1: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts/opentype: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/opentype/urw-base35: caching, new cache contents: 35 fonts, 0 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 5 dirs
# /usr/share/fonts/truetype/crosextra: caching, new cache contents: 8 fonts, 0 dirs
# /usr/share/fonts/truetype/droid: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/msttcorefonts: caching, new cache contents: 60 fonts, 0 dirs
# /usr/share/fonts/type1: caching, new cache contents: 0 fonts, 2 dirs
# /usr/share/fonts/type1/gsfonts: caching, new cache contents: 35 fonts, 0 dirs
# /usr/share/fonts/type1/urw-base35: caching, new cache contents: 35 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/texmf/fonts/opentype/public/lm: caching, new cache contents: 72 fonts, 0 dirs
# /usr/share/texmf/fonts/opentype/public/lm-math: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/X11: skipping, looped directory detected
# /usr/share/fonts/cMap: skipping, looped directory detected
# /usr/share/fonts/cmap: skipping, looped directory detected
# /usr/share/fonts/opentype: skipping, looped directory detected
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/type1: skipping, looped directory detected
# /usr/share/fonts/X11/Type1: skipping, looped directory detected
# /usr/share/fonts/X11/encodings: skipping, looped directory detected
# /usr/share/fonts/X11/util: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-cns1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-gb1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-japan1: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-japan2: skipping, looped directory detected
# /usr/share/fonts/cmap/adobe-korea1: skipping, looped directory detected
# /usr/share/fonts/opentype/urw-base35: skipping, looped directory detected
# /usr/share/fonts/truetype/crosextra: skipping, looped directory detected
# /usr/share/fonts/truetype/droid: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/msttcorefonts: skipping, looped directory detected
# /usr/share/fonts/type1/gsfonts: skipping, looped directory detected
# /usr/share/fonts/type1/urw-base35: skipping, looped directory detected
# /usr/share/fonts/X11/encodings/large: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded
# Font cache updated

# %%
# 2. Install olmOCR
# !pip install git+https://github.com/allenai/olmocr.git
# Out:
# Collecting git+https://github.com/allenai/olmocr.git
#   Cloning https://github.com/allenai/olmocr.git to /tmp/pip-req-build-ne3siuzk
#   Running command git clone --filter=blob:none --quiet https://github.com/allenai/olmocr.git /tmp/pip-req-build-ne3siuzk
#   Resolved https://github.com/allenai/olmocr.git to commit b62ccc25ddaa547de778d8d72fe1e2d41ab8a0a3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cached-path in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (1.6.7)
# Requirement already satisfied: smart_open in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (7.1.0)
# Requirement already satisfied: pypdf>=5.2.0 in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (5.3.1)
# Requirement already satisfied: pypdfium2 in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (4.30.1)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (43.0.3)
# Requirement already satisfied: lingua-language-detector in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (11.1.0)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (6.3.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (6.2.0)
# Requirement already satisfied: markdown2 in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (2.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (3.17.0)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (3.10.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (2.32.3)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (0.23.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (1.37.7)
# Requirement already satisfied: httpx in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (0.28.1)
# Requirement already satisfied: torch>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (2.5.1+cu124)
# Requirement already satisfied: transformers>=4.46.2 in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (4.48.3)
# Requirement already satisfied: beaker-py in /usr/local/lib/python3.11/dist-packages (from olmocr==0.1.59) (1.34.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5.1->olmocr==0.1.59) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.5.1->olmocr==0.1.59) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.2->olmocr==0.1.59) (0.27.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.2->olmocr==0.1.59) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.2->olmocr==0.1.59) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.2->olmocr==0.1.59) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.2->olmocr==0.1.59) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.2->olmocr==0.1.59) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.2->olmocr==0.1.59) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.2->olmocr==0.1.59) (4.67.1)
# Requirement already satisfied: pydantic<3.0,>=1.8.2 in /usr/local/lib/python3.11/dist-packages (from beaker-py->olmocr==0.1.59) (2.10.6)
# Requirement already satisfied: rich<14.0,>=12.3 in /usr/local/lib/python3.11/dist-packages (from beaker-py->olmocr==0.1.59) (13.9.4)
# Requirement already satisfied: docker<8.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from beaker-py->olmocr==0.1.59) (7.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->olmocr==0.1.59) (0.5.1)
# Requirement already satisfied: botocore<1.38.0,>=1.37.7 in /usr/local/lib/python3.11/dist-packages (from boto3->olmocr==0.1.59) (1.37.7)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from boto3->olmocr==0.1.59) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3->olmocr==0.1.59) (0.11.4)
# Requirement already satisfied: google-cloud-storage<3.0,>=1.32.0 in /usr/local/lib/python3.11/dist-packages (from cached-path->olmocr==0.1.59) (2.19.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography->olmocr==0.1.59) (1.17.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->olmocr==0.1.59) (0.2.13)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx->olmocr==0.1.59) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx->olmocr==0.1.59) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx->olmocr==0.1.59) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx->olmocr==0.1.59) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx->olmocr==0.1.59) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->olmocr==0.1.59) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->olmocr==0.1.59) (2.3.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart_open->olmocr==0.1.59) (1.17.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.7->boto3->olmocr==0.1.59) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography->olmocr==0.1.59) (2.22)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (2.38.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (2.24.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (2.4.2)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (1.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0,>=1.8.2->beaker-py->olmocr==0.1.59) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0,>=1.8.2->beaker-py->olmocr==0.1.59) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich<14.0,>=12.3->beaker-py->olmocr==0.1.59) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich<14.0,>=12.3->beaker-py->olmocr==0.1.59) (2.18.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx->olmocr==0.1.59) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.5.1->olmocr==0.1.59) (3.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (1.69.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (1.26.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (4.9)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=12.3->beaker-py->olmocr==0.1.59) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.7->boto3->olmocr==0.1.59) (1.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage<3.0,>=1.32.0->cached-path->olmocr==0.1.59) (0.6.1)

# %%
# 3. Install sglang with flashinfer (for GPU acceleration)
# Note: These versions may need to be updated depending on your Colab environment
# !pip install sgl-kernel==0.0.3.post1 --force-reinstall --no-deps
try:
    # !pip install "sglang[all]==0.4.2" --find-links https://flashinfer.ai/whl/cu124/torch2.4/flashinfer/
except:
    print("Failed to install sglang with flashinfer. Installing without GPU acceleration.")
    # !pip install "sglang[all]==0.4.2"
# Out:
# Collecting sgl-kernel==0.0.3.post1
#   Using cached sgl_kernel-0.0.3.post1-cp39-abi3-manylinux2014_x86_64.whl.metadata (13 kB)
# Using cached sgl_kernel-0.0.3.post1-cp39-abi3-manylinux2014_x86_64.whl (9.1 MB)
# Installing collected packages: sgl-kernel
#   Attempting uninstall: sgl-kernel
#     Found existing installation: sgl-kernel 0.0.3.post1
#     Uninstalling sgl-kernel-0.0.3.post1:
#       Successfully uninstalled sgl-kernel-0.0.3.post1
# Successfully installed sgl-kernel-0.0.3.post1
# Looking in links: https://flashinfer.ai/whl/cu124/torch2.4/flashinfer/
# Requirement already satisfied: sglang==0.4.2 in /usr/local/lib/python3.11/dist-packages (from sglang[all]==0.4.2) (0.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (1.26.4)
# Requirement already satisfied: IPython in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (7.34.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (1.3.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from IPython->sglang==0.4.2->sglang[all]==0.4.2) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from IPython->sglang==0.4.2->sglang[all]==0.4.2) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from IPython->sglang==0.4.2->sglang[all]==0.4.2) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from IPython->sglang==0.4.2->sglang[all]==0.4.2) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from IPython->sglang==0.4.2->sglang[all]==0.4.2) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from IPython->sglang==0.4.2->sglang[all]==0.4.2) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from IPython->sglang==0.4.2->sglang[all]==0.4.2) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from IPython->sglang==0.4.2->sglang[all]==0.4.2) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from IPython->sglang==0.4.2->sglang[all]==0.4.2) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from IPython->sglang==0.4.2->sglang[all]==0.4.2) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->sglang==0.4.2->sglang[all]==0.4.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->sglang==0.4.2->sglang[all]==0.4.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->sglang==0.4.2->sglang[all]==0.4.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->sglang==0.4.2->sglang[all]==0.4.2) (2025.1.31)
# Requirement already satisfied: anthropic>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.49.0)
# Requirement already satisfied: litellm>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (1.63.2)
# Requirement already satisfied: openai>=1.0 in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (1.61.1)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.9.0)
# Requirement already satisfied: cuda-python in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (12.6.2.post1)
# Requirement already satisfied: sgl-kernel>=0.0.3 in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.0.3.post1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (2.5.1+cu124)
# Requirement already satisfied: vllm==0.6.4.post1 in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.6.4.post1)
# Requirement already satisfied: flashinfer==0.1.6 in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.1.6+cu124torch2.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.2.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (9.0.0)
# Requirement already satisfied: transformers>=4.45.2 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (4.48.3)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.21.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (4.25.6)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (3.11.13)
# Requirement already satisfied: uvicorn[standard] in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.34.0)
# Requirement already satisfied: pydantic>=2.9 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (2.10.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (11.1.0)
# Requirement already satisfied: prometheus-client>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.21.1)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (7.0.2)
# Requirement already satisfied: lm-format-enforcer<0.11,>=0.10.9 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.10.11)
# Requirement already satisfied: outlines<0.1,>=0.0.43 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.0.46)
# Requirement already satisfied: typing-extensions>=4.10 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (4.12.2)
# Requirement already satisfied: filelock>=3.10.4 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (3.17.0)
# Requirement already satisfied: partial-json-parser in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.2.1.1.post5)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (26.2.1)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.19.0)
# Requirement already satisfied: gguf==0.10.0 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.10.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (8.6.1)
# Requirement already satisfied: mistral-common>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from mistral-common[opencv]>=1.5.0->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (1.5.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (6.0.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.8.1)
# Requirement already satisfied: compressed-tensors==0.8.0 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.8.0)
# Requirement already satisfied: ray>=2.9 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (2.43.0)
# Requirement already satisfied: nvidia-ml-py>=12.560.30 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (12.570.86)
# Requirement already satisfied: torchvision==0.20.1 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.20.1+cu124)
# Requirement already satisfied: xformers==0.0.28.post3 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.0.28.post3)
# Requirement already satisfied: fastapi!=0.113.*,!=0.114.0,>=0.107.0 in /usr/local/lib/python3.11/dist-packages (from vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.115.11)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (2024.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->sglang==0.4.2->sglang[all]==0.4.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->sglang==0.4.2->sglang[all]==0.4.2) (1.3.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from anthropic>=0.20.0->sglang==0.4.2->sglang[all]==0.4.2) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from anthropic>=0.20.0->sglang==0.4.2->sglang[all]==0.4.2) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from anthropic>=0.20.0->sglang==0.4.2->sglang[all]==0.4.2) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from anthropic>=0.20.0->sglang==0.4.2->sglang[all]==0.4.2) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from anthropic>=0.20.0->sglang==0.4.2->sglang[all]==0.4.2) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->IPython->sglang==0.4.2->sglang[all]==0.4.2) (0.8.4)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from litellm>=1.0.0->sglang==0.4.2->sglang[all]==0.4.2) (8.1.8)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm>=1.0.0->sglang==0.4.2->sglang[all]==0.4.2) (4.23.0)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from litellm>=1.0.0->sglang==0.4.2->sglang[all]==0.4.2) (1.0.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->IPython->sglang==0.4.2->sglang[all]==0.4.2) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->sglang==0.4.2->sglang[all]==0.4.2) (0.2.13)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken->sglang==0.4.2->sglang[all]==0.4.2) (2024.11.6)
# Requirement already satisfied: decord in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.6.0)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.1.9)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.27.1)
# Requirement already satisfied: interegular in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.3.3)
# Requirement already satisfied: modelscope in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (1.23.2)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (3.10.15)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (24.2)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.0.20)
# Requirement already satisfied: torchao>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.9.0)
# Requirement already satisfied: uvloop in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.21.0)
# Requirement already satisfied: xgrammar>=0.1.10 in /usr/local/lib/python3.11/dist-packages (from sglang==0.4.2->sglang[all]==0.4.2) (0.1.15)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi!=0.113.*,!=0.114.0,>=0.107.0->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.46.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->anthropic>=0.20.0->sglang==0.4.2->sglang[all]==0.4.2) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic>=0.20.0->sglang==0.4.2->sglang[all]==0.4.2) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->sglang==0.4.2->sglang[all]==0.4.2) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.0.0->sglang==0.4.2->sglang[all]==0.4.2) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.0.0->sglang==0.4.2->sglang[all]==0.4.2) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.0.0->sglang==0.4.2->sglang[all]==0.4.2) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.0.0->sglang==0.4.2->sglang[all]==0.4.2) (0.23.1)
# Requirement already satisfied: opencv-python-headless>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mistral-common[opencv]>=1.5.0->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (4.11.0.86)
# Requirement already satisfied: lark in /usr/local/lib/python3.11/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (1.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (1.6.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (3.1.1)
# Requirement already satisfied: diskcache in /usr/local/lib/python3.11/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (5.6.3)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.60.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (3.3.2)
# Requirement already satisfied: pycountry in /usr/local/lib/python3.11/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (24.6.1)
# Requirement already satisfied: pyairports in /usr/local/lib/python3.11/dist-packages (from outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (2.1.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.9->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (2.27.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (1.1.0)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray>=2.9->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (1.5.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.45.2->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.5.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (2.4.6)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (1.18.3)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (14.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets->outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.70.16)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets->outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets->outlines<0.1,>=0.0.43->vllm==0.6.4.post1->sglang==0.4.2->sglang[all]==0.4.2) (1.17.0)

# %%
# Install required libraries
# !pip install zstandard tqdm webdavclient3 -q

# %%
# !pip install pikepdf
# Out:
# Requirement already satisfied: pikepdf in /usr/local/lib/python3.11/dist-packages (9.5.2)
# Requirement already satisfied: Pillow>=10.0.1 in /usr/local/lib/python3.11/dist-packages (from pikepdf) (11.1.0)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from pikepdf) (1.2.18)
# Requirement already satisfied: lxml>=4.8 in /usr/local/lib/python3.11/dist-packages (from pikepdf) (5.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from pikepdf) (24.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->pikepdf) (1.17.2)

# %%
# Install required libraries (if not already installed)
# !pip install webdavclient3 tqdm

import os
from webdav3.client import Client
from google.colab import userdata  # For accessing Colab secrets
from tqdm import tqdm

# --- 1. Set Up Workspace Directories ---
# Updated workspace to "olmocr_workspace_rest"
drive_workspace = "/content/drive/MyDrive/olmocr_workspace_rest"
drive_pdfs_dir = os.path.join(drive_workspace, "pdfs_to_process")
os.makedirs(drive_workspace, exist_ok=True)
os.makedirs(drive_pdfs_dir, exist_ok=True)
print(f"Workspace directory created: {drive_workspace}")

# --- 2. Retrieve WebDAV Credentials from Colab Secrets ---
webdav_username = userdata.get('WEBDAV_USERNAME')
webdav_password = userdata.get('WEBDAV_PASSWORD')
webdav_url      = userdata.get('WEBDAV_URL')  # e.g., "https://files.chao.eu/remote.php/dav/files/admin/"
if not (webdav_username and webdav_password and webdav_url):
    raise ValueError("Missing one or more WebDAV secrets: WEBDAV_USERNAME, WEBDAV_PASSWORD, WEBDAV_URL")

# --- 3. Configure the WebDAV Client ---
options = {
    'webdav_hostname': webdav_url,
    'webdav_login':    webdav_username,
    'webdav_password': webdav_password
}
client = Client(options)
# Remove the insecure setting so that certificate verification happens
# client.verify = False  # Do not disable verification for production!
print("Connected to WebDAV.")

# --- 4. Define the Remote Directory Containing PDFs ---
# This should correspond to the folder from which you want to download PDFs.
remote_pdf_dir = "DT/olmocr_backups/missing_pdfs"

# --- 5. List the PDF Files in the Remote Directory ---
try:
    remote_files = client.list(remote_pdf_dir)
    # Filter out only PDF files (case-insensitive)
    pdf_files = [f for f in remote_files if f.lower().endswith('.pdf')]
    print(f"Found {len(pdf_files)} PDF files in remote directory '{remote_pdf_dir}'.")
except Exception as e:
    print(f"Error listing remote directory: {e}")
    pdf_files = []

# --- 6. Download the PDF Files to the "olmocr_workspace_missing" Directory ---
if pdf_files:
    pbar = tqdm(total=len(pdf_files), desc="Downloading PDFs", unit="file")
    for file in pdf_files:
        # If the file path doesn't start with the remote directory, prepend it.
        if not file.startswith(remote_pdf_dir):
            remote_file_path = os.path.join(remote_pdf_dir, file)
        else:
            remote_file_path = file
        local_file_path = os.path.join(drive_pdfs_dir, os.path.basename(file))
        try:
            client.download_file(remote_file_path, local_file_path)
            pbar.update(1)
        except Exception as e:
            print(f"Error downloading {file}: {e}")
    pbar.close()
    print(f"Downloaded {len(pdf_files)} PDF files to {drive_pdfs_dir}.")
else:
    print("No PDF files found in remote directory.")
# Out:
# Requirement already satisfied: webdavclient3 in /usr/local/lib/python3.11/dist-packages (3.14.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from webdavclient3) (2.32.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from webdavclient3) (5.3.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from webdavclient3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil->webdavclient3) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->webdavclient3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->webdavclient3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->webdavclient3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->webdavclient3) (2025.1.31)
# Workspace directory created: /content/drive/MyDrive/olmocr_workspace_rest
# Connected to WebDAV.
# Found 6 PDF files in remote directory 'DT/olmocr_backups/missing_pdfs'.
# Downloading PDFs:  67%|██████▋   | 4/6 [00:21<00:10,  5.24s/file]

# %%
# !python -m olmocr.pipeline /content/drive/MyDrive/olmocr_workspace_missing --pdfs /content/drive/MyDrive/olmocr_workspace_rest/pdfs_to_process/*.pdf --workers 1
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 12 threads.
# ERROR:olmocr.check:pdftoppm is not installed.
# ERROR:olmocr.check:Check the README in the https://github.com/allenai/olmocr/blob/main/README.md for installation instructions
